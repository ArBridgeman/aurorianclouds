# %%
from IPython.core.getipython import get_ipython

get_ipython().run_line_magic("load_ext", "autoreload")
get_ipython().run_line_magic("autoreload", "2")

from datetime import datetime, timedelta
from pathlib import Path
import logging
from hydra import compose, initialize

import numpy as np
from omegaconf import DictConfig
from sous_chef.date.get_due_date import DueDatetimeFormatter
# from sous_chef.formatter.format_unit import UnitFormatter
# from sous_chef.formatter.ingredient.format_ingredient import IngredientFormatter
from sous_chef.menu.create_menu.create_menu import Menu
from sous_chef.menu.create_menu._from_fixed_template import FixedTemplates
from sous_chef.menu.record_menu_history import MenuHistorian
# from sous_chef.pantry_list.read_pantry_list import PantryList
from sous_chef.recipe_book.read_recipe_book import RecipeBook
from sous_chef.rtk.read_write_rtk import RtkService
from sous_chef.menu.main import _get_ingredient_formatter
from structlog import get_logger

from utilities.api.gsheets_api import GsheetsHelper
# from utilities.api.todoist_api import TodoistHelper

# %%
def update_data():
    with initialize(
            version_base=None, config_path="../../sous-chef/config/"
    ):
        config = compose(config_name="menu_main")
        rtk_service = RtkService(config.rtk)
        rtk_service.unzip()

def get_recipe_book():
    with initialize(
            version_base=None, config_path="../../sous-chef/config/"
    ):
        config = compose(config_name="menu_main")
        return RecipeBook(config.recipe_book)
    
def get_menu_historian():
    with initialize(
            version_base=None, config_path="../../sous-chef/config/"
    ):
        config = compose(config_name="menu_main")
        gsheets_helper = GsheetsHelper(config.api.gsheets)
        due_date_formatter = DueDatetimeFormatter(config=config.date.due_date)

        menu_historian = MenuHistorian(
            config=config.menu.record_menu_history,
            current_menu_start_date=due_date_formatter.get_anchor_datetime()
                                    + timedelta(days=1),
            gsheets_helper=gsheets_helper,
        )
        
        return menu_historian
    
def create_menu(recipe_book: RecipeBook, menu_historian: MenuHistorian) -> Menu:
    with initialize(
            version_base=None, config_path="../../sous-chef/config/"
    ):
        config = compose(config_name="menu_main")
        
        gsheets_helper = GsheetsHelper(config.api.gsheets)
        due_date_formatter = DueDatetimeFormatter(config=config.date.due_date)
        ingredient_formatter = _get_ingredient_formatter(config, gsheets_helper)

        menu = Menu(
            config=config.menu.create_menu,
            due_date_formatter=due_date_formatter,
            gsheets_helper=gsheets_helper,
            ingredient_formatter=ingredient_formatter,
            menu_historian=menu_historian,
            recipe_book=recipe_book,
        )
    return menu

def get_menu_history_uuids(menu_historian: MenuHistorian):
    with initialize(
            version_base=None, config_path="../../sous-chef/config/"
    ):
        config = compose(config_name="menu_main")
        
        history = menu_historian.get_history_from(
            days_ago=config.menu.create_menu.menu_history_recent_days
        )
        
        return list(history.uuid.values)
    
def get_future_menu_uuids(menu: Menu, future_menus: int = None):

        fixed_templates = FixedTemplates(
            config=menu.config.fixed,
            due_date_formatter=menu.due_date_formatter,
            gsheets_helper=menu.gsheets_helper,
        )

        future_uuid_tuple = menu._get_future_menu_uuids(
            future_menus=fixed_templates.select_upcoming_menus(
                num_weeks_in_future=future_menus if future_menus else menu.config.fixed.already_in_future_menus.num_weeks  # noqa: E501
            )
        )
        
        return future_uuid_tuple

# %%
# logging.getLogger().setLevel(logging.CRITICAL)

update_data()
recipes = get_recipe_book()
# Out:
# 2024-03-08 15:29:43 [info     ] [format recipe row]            recipe= Lentil Soup
# 2024-03-08 15:29:43 [info     ] [format recipe row]            recipe=15-Hour TikTok Potatoes
# 2024-03-08 15:29:43 [info     ] [format recipe row]            recipe=2-Layer Lemon Bites
# 2024-03-08 15:29:43 [info     ] [format recipe row]            recipe=2-Minute Healthy Ketchup
# 2024-03-08 15:29:43 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:43 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:43 [info     ] [format recipe row]            recipe
# 2024-03-08 15:29:43 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:43 [info     ] [format recipe row]            recipe=Baked Sweet Potatoes Stuffed with Feta, Olives and Sundried Tomatoes
# 2024-03-08 15:29:43 [warning  ] [create_timedelta] conversion failed entry=
# ...
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Egg Tofu (Tamago Tofu)
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Egg bhurji
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Egg sandwich
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Eggnog Hawaiian Roll French Toast
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Eggplant Caviar with Roasted Red Peppers
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Eggplant Parmigiana Recipe
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Eggplant String Bean Stir-fry
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Eggplant tomato caprese stacks
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Eggplant with Garlic Sauce
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Eggplant with Garlic Sauce 2
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Eggplant with Garlic Sauce 3
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Eggs Benedict
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Eggs Benedict Baked Potatoes
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Eggs in a Bagel Hole
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Eggs in a Boat
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Eggs with Soy Sauce & Scallions
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Eggs with chorizo & Bratkartoffeln
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Eggs with lentils and spiced mint
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Electric Lemonade
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Elven banana bread
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Empanada dough
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Empress Chicken
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Enchiladas de Suelo
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Endorian Roasted Chicken Salad
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=English Muffin Bread
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=English Toffee
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=English muffins
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Ensalada Caesar de Ejotes
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Epcot Wild Berry Buckle
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Epic Breakfast Tacos
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Epic Spanish Potatoes with Wine, Saffron & Rosemary
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Erbseneintopf mit Würstchen
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Ermine Buttercream
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Escarole and Radicchio Salad with Honey-Mustard Vinaigrette Recipe
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Everything Bagel Chili Crisp (vegan, gluten free)
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Everything Bagel Dip
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Everything Bagel Focaccia
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Everything Bagel Seasoning
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Everything Bagel Vegan Cheese Ball - 10 Minute
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Everything chicken fingers
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Extra Crispy Halloumi Nuggets
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Extra Vegetable Fried Rice
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Extra-Bittersweet Chocolate Pots de Crème
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Ezme Recipe (Turkish Acili Ezme)
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Fabulously Healthy Buckwheat Pancakes
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Fajita Chicken Burrito Bowl
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Fajita in a Bowl
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Falafel
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Falafel 2
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Fall Chop Salad
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Fancy Roasted Nuts
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Farmers Market Frittata
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Fergus Henderson's Red Salad
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Fermented Cashew Cheese
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Ferrero Rocher Dates
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Ferrero Rocher Overnight Oats
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Feta Cheese Dip
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Feta Grilled Cheese With Honey
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Feta Marinated with Herbs and Chilli
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Feta Pizza With Tomato and Basil
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Feta and red pepper quiche
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Feta bruschetta
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Fettuccine Alfredo
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Fiesta Lime Chicken
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Fiesta Lime Salad
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Filipino Chicken Asado (Kapampangan style)
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Filipino Garlic Rice
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Fingerling Potato and Arugula Salad
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Firecracker Salmon
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Firecracker Vegan Lettuce Wraps
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Fish Florentine
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Fish Taco Sauce
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Fish Tacos
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Fish pie
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Fish with salmoriglio sauce
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Five Cheese Ziti al Forno
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Five Spice and Garlic Roasted Potatoes
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Five-cheese Mac and Cheese Recipe by Tasty
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Flame Tree BBQ Sauce - D23
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Flaming Salmon Sushi
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Flammkuchen dough
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] [format recipe row]            recipe=Flan
# 2024-03-08 15:29:51 [warning  ] [create_timedelta] conversion failed entry=
# 2024-03-08 15:29:51 [info     ] Recipe book stats              num_rated=919 num_total=4515

# %%
menu_historian = get_menu_historian()
menu = create_menu(recipes, menu_historian)
# Out:
# 2024-03-08 15:29:51 [info     ] [get_worksheet]                workbook_name=menu-history worksheet_name=menu-history
# 2024-03-08 15:29:55 [info     ] [get_worksheet]                workbook_name=pantry_list worksheet_name=ingredients
# 2024-03-08 15:29:57 [info     ] [get_worksheet]                workbook_name=pantry_list worksheet_name=replacement_ingredients
# 2024-03-08 15:29:58 [info     ] [get_worksheet]                workbook_name=pantry_list worksheet_name=bad_ingredients
# 2024-03-08 15:29:59 [info     ] [get_worksheet]                workbook_name=pantry_list worksheet_name=misspelled_ingredients
# 2024-03-08 15:30:01 [warning  ] Empty DataFrame
# Columns: [replacement_ingredient, plural_ending, replace_factor, replace_unit, true_ingredient, item_plural, misspelled_ingredient, label, _merge]
# Index: []
# 2024-03-08 15:30:01 [warning  ] Empty DataFrame
# Columns: [ingredient, plural_ending, is_staple, group, store, recipe_uuid, barcode, item_plural, misspelled_ingredient, true_ingredient, label, replace_factor, replace_unit, _merge]
# Index: []

# %%
current_menu = menu.load_final_menu()
menu.config.fixed.menu_number = 6

menu_history = get_menu_history_uuids(menu_historian)
menu_future = get_future_menu_uuids(menu, future_menus=15)
# Out:
# 2024-03-08 15:30:01 [info     ] [get_worksheet]                workbook_name=menu-tmp worksheet_name=menu-tmp
# 2024-03-08 15:30:03 [info     ] [_get_all_fixed_menus]
# 2024-03-08 15:30:03 [info     ] [get_worksheet]                workbook_name=fixed_menus worksheet_name=breakfast
# 2024-03-08 15:30:06 [info     ] [get_worksheet]                workbook_name=fixed_menus worksheet_name=snack
# 2024-03-08 15:30:09 [info     ] [get_worksheet]                workbook_name=fixed_menus worksheet_name=dinner
# 2024-03-08 15:30:13 [info     ] [get_worksheet]                workbook_name=fixed_menus worksheet_name=dessert
# 2024-03-08 15:30:15 [info     ] [select_upcoming_menus]
# 2024-03-08 15:30:15 [info     ] [_get_future_menu_uuids]
# ---------------------------------------------------------------------------
# FuzzySearchError                          Traceback (most recent call last)
# File ~/code_private/aurorianclouds/sous-chef/sous_chef/recipe_book/_recipe_book.py:63, in RecipeBasic.get_recipe_by_title(self, title)
#      62 try:
# ---> 63     recipe = self.retrieve_match(field="title", search_term=title)
#      64     self._check_total_time(recipe)
#
# File ~/code_private/aurorianclouds/sous-chef/sous_chef/abstract/search_dataframe.py:67, in DataframeSearchable.retrieve_match(self, field, search_term)
#      66 try:
# ---> 67     found_recipe = retrieval_method(field, search_term)
#      68     return found_recipe
#
# File ~/code_private/aurorianclouds/sous-chef/sous_chef/abstract/search_dataframe.py:86, in DataframeSearchable._retrieve_fuzzy_fallback(self, field, search_term)
#      85 if best_match_quality < min_threshold_to_accept:
# ---> 86     raise FuzzySearchError(
#      87         field=field,
#      88         search_term=search_term,
#      89         result=best_match_search_term,
#      90         match_quality=best_match_quality,
#      91         threshold=min_threshold_to_accept,
#      92     )
#      94 min_thresh_ok_match = self.config.fuzzy_match.min_thresh_ok_match
#
# FuzzySearchError: [fuzzy search failed]: {'field': 'title', 'search_term': 'joint-snack/special', 'result': 'lentil spinach salad', 'quality': 56, 'threshold': 90}
#
# During handling of the above exception, another exception occurred:
#
# RecipeNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 5
#       2 menu.config.fixed.menu_number = 6
#       4 menu_history = get_menu_history_uuids(menu_historian)
# ----> 5 menu_future = get_future_menu_uuids(menu, future_menus=15)
#
# Cell In[2], line 73, in get_future_menu_uuids(menu, future_menus)
#      65 def get_future_menu_uuids(menu: Menu, future_menus: int = None):
#      67         fixed_templates = FixedTemplates(
#      68             config=menu.config.fixed,
#      69             due_date_formatter=menu.due_date_formatter,
#      70             gsheets_helper=menu.gsheets_helper,
#      71         )
# ---> 73         future_uuid_tuple = menu._get_future_menu_uuids(
#      74             future_menus=fixed_templates.select_upcoming_menus(
#      75                 num_weeks_in_future=future_menus if future_menus else menu.config.fixed.already_in_future_menus.num_weeks  # noqa: E501
#      76             )
#      77         )
#      79         return future_uuid_tuple
#
# File ~/code_private/aurorianclouds/sous-chef/sous_chef/menu/create_menu/_from_fixed_template.py:100, in MenuFromFixedTemplate._get_future_menu_uuids(self, future_menus)
#      98 FILE_LOGGER.info("[_get_future_menu_uuids]")
#      99 mask_type = future_menus["type"] == "recipe"
# --> 100 return tuple(
#     101     self.recipe_book.get_recipe_by_title(recipe).uuid
#     102     for recipe in future_menus[mask_type]["item"].values
#     103 )
#
# File ~/code_private/aurorianclouds/sous-chef/sous_chef/menu/create_menu/_from_fixed_template.py:101, in <genexpr>(.0)
#      98 FILE_LOGGER.info("[_get_future_menu_uuids]")
#      99 mask_type = future_menus["type"] == "recipe"
#     100 return tuple(
# --> 101     self.recipe_book.get_recipe_by_title(recipe).uuid
#     102     for recipe in future_menus[mask_type]["item"].values
#     103 )
#
# File ~/code_private/aurorianclouds/sous-chef/sous_chef/recipe_book/_recipe_book.py:67, in RecipeBasic.get_recipe_by_title(self, title)
#      65     return recipe.copy(deep=True)
#      66 except FuzzySearchError as e:
# ---> 67     raise RecipeNotFoundError(recipe_title=title, search_results=str(e))
#
# RecipeNotFoundError: [recipe not found] recipe=joint-snack/special search_results=[[fuzzy search failed]: {'field': 'title', 'search_term': 'joint-snack/special', 'result': 'lentil spinach salad', 'quality': 56, 'threshold': 90}]

# %%
recipe_df = recipes.dataframe.copy()
recipe_df.reset_index(drop=True)
display(recipe_df)

# %%
old_len = recipe_df.shape[0]
recipe_history_df = recipe_df[recipe_df.uuid.isin(menu_history)]

recipe_df = recipe_df[~recipe_df.uuid.isin(menu_history)]
recipe_df = recipe_df[~recipe_df.uuid.isin(menu_future)]
print(f"Selected {recipe_df.shape[0]} from total of {old_len} recipes")

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output, HTML

# %%
unique_cats = (recipe_df.categories.explode().sort_values().unique().tolist())
unique_tags = (recipe_df.tags.explode().unique().tolist())

# %%
# recipe_df.categories.astype(str).str.contains('drink')

# %%
dropdown_cat = widgets.Dropdown(options = unique_cats, description='Category:')
# dropdown_tag1 = widgets.Dropdown(options = unique_tags, description='Tag 1:')
text_tag1 = widgets.Text(value='', description='Tags 1 (or):', continuous_update=False, disabled=False)
text_tag2 = widgets.Text(value='', description='Tags 2 (or):', continuous_update=False, disabled=False)
text_tag3 = widgets.Text(value='', description='Tags 3 (or):', continuous_update=False, disabled=False)

col_sel = ["title", "rating", "time_total", "ingredients", "categories", "tags"]
sort_cols = ["rating"]
top_show = 10

# Create output widget
output = widgets.Output()

def dropdown_eventhandler(change):
    with output:
        clear_output()
        mask = recipe_df['categories'].astype(str).str.contains(dropdown_cat.value)
        for text_tag in [text_tag1, text_tag2, text_tag3]:
            if text_tag.value != '':
                sub_mask = np.zeros(len(mask), dtype=bool)
                all_vals = text_tag.value.split(',')
                for val in all_vals:
                    sub_mask |= recipe_df['tags'].astype(str).str.contains(val.strip())
                mask &= sub_mask
        display(HTML(recipe_df[mask][col_sel].sort_values(by=sort_cols, ascending=False).head(top_show).to_html(index=False)))
    
dropdown_cat.observe(dropdown_eventhandler, names='value')
# Bind function to text box value change
text_tag1.observe(dropdown_eventhandler, names='value')
text_tag2.observe(dropdown_eventhandler, names='value')
text_tag3.observe(dropdown_eventhandler, names='value')

display(dropdown_cat)
display(text_tag1)
display(text_tag2)
display(text_tag3)

display(output)
